# %%
import pandas as pd

# %%
def load_sales_data(file_path):
    sales_data = pd.read_csv(file_path)
    return sales_data

data = load_sales_data('D:\\Sale Performance Analysis September 2024\\Sale-Team-Performance-Analysis-Using-LLM\\data\\sales_performance_data.csv')

# %%
data.head()
# Out:
#    employee_id  employee_name                  created       dated  \
# 0          183    Camilla Ali  2022-07-26 19:00:12.644  2022-07-26
# 1          185     Maaz Brown  2022-07-26 19:00:12.644  2022-07-26
# 2          186        Jim Lee  2022-07-26 19:00:12.644  2022-07-26
# 3          173   Alina Victor  2022-07-26 19:00:12.644  2022-07-26
# 4          158  Mary Ogbewele  2022-07-26 19:00:12.644  2022-07-26
#
#    lead_taken  tours_booked  applications  tours_per_lead  apps_per_tour  \
# 0          44             2             2             4.5          100.0
# 1          27             1             0             3.7            0.0
# 2          86             5             1             5.8           20.0
# 3          47             8             4            17.0           50.0
# 4          56             6             3            10.7           50.0
#
#    apps_per_lead  ...  fri_text  sat_text  sun_text  mon_call  tue_call  \
# 0            4.5  ...        11         5        86         0         3
# 1            0.0  ...        27        28        21         2         1
# 2            1.2  ...        10        14         0         0         2
# 3            8.5  ...        10        20         6         4         5
# 4            5.4  ...        56        52        13         5        12
#
#    wed_call  thur_call  fri_call  sat_call  sun_call
# 0         2          6         0         0        13
# 1         0          2         3         1         3
# 2         0          0         0         0         0
# 3        13          1         6        10         1
# 4         0          3        11         0         2
#
# [5 rows x 36 columns]

# %%
def preprocess_data(sales_data):
    # Handle missing values
    sales_data.fillna(0, inplace=True)
    
    # Calculate overall conversion rates
    sales_data['conversion_rate'] = sales_data['applications'] / sales_data['lead_taken'].replace(0, 1)
    return sales_data

processed_data = preprocess_data(data)

# %%
processed_data
# Out:
#       employee_id  employee_name                  created       dated  \
# 0             183    Camilla Ali  2022-07-26 19:00:12.644  2022-07-26
# 1             185     Maaz Brown  2022-07-26 19:00:12.644  2022-07-26
# 2             186        Jim Lee  2022-07-26 19:00:12.644  2022-07-26
# 3             173   Alina Victor  2022-07-26 19:00:12.644  2022-07-26
# 4             158  Mary Ogbewele  2022-07-26 19:00:12.644  2022-07-26
# ...           ...            ...                      ...         ...
# 2531          146    Travis Reed  2023-05-10 13:20:20.742  2023-05-10
# 2532          144              0  2023-05-10 13:20:20.742  2023-05-10
# 2533           94  Richard Crown  2023-05-10 13:20:20.742  2023-05-10
# 2534           84   Rebecca Zara  2023-05-10 13:20:20.742  2023-05-10
# 2535          149    Mary Farley  2023-05-10 13:20:20.742  2023-05-10
#
#       lead_taken  tours_booked  applications  tours_per_lead  apps_per_tour  \
# 0             44             2             2             4.5          100.0
# 1             27             1             0             3.7            0.0
# 2             86             5             1             5.8           20.0
# 3             47             8             4            17.0           50.0
# 4             56             6             3            10.7           50.0
# ...          ...           ...           ...             ...            ...
# 2531           3             0             0             0.0           -1.0
# 2532           0             0             0             0.0            0.0
# 2533          25             2             0             8.0            0.0
# 2534           5             1             1            20.0          100.0
# 2535           0             0             0             0.0            0.0
#
#       apps_per_lead  ...  sat_text  sun_text  mon_call  tue_call  wed_call  \
# 0               4.5  ...         5        86         0         3         2
# 1               0.0  ...        28        21         2         1         0
# 2               1.2  ...        14         0         0         2         0
# 3               8.5  ...        20         6         4         5        13
# 4               5.4  ...        52        13         5        12         0
# ...             ...  ...       ...       ...       ...       ...       ...
# 2531            0.0  ...         0         0         0         0         0
# 2532            0.0  ...         0         0         0         0         0
# 2533            0.0  ...        98         3        13         2        18
# 2534           20.0  ...        62        47         6        49         8
# 2535            0.0  ...         0         0         0         0         0
#
#       thur_call  fri_call  sat_call  sun_call  conversion_rate
# 0             6         0         0        13         0.045455
# 1             2         3         1         3         0.000000
# 2             0         0         0         0         0.011628
# 3             1         6        10         1         0.085106
# 4             3        11         0         2         0.053571
# ...         ...       ...       ...       ...              ...
# 2531          0         0         0         0         0.000000
# 2532          0         0         0         0         0.000000
# 2533         12         1        18         0         0.000000
# 2534         11         2        14        12         0.200000
# 2535          0         0         0         0         0.000000
#
# [2536 rows x 37 columns]

# %%
def summarize_by_employee(sales_data):
    employee_summary = sales_data.groupby('employee_name').agg({
        'lead_taken': 'sum',
        'tours_booked': 'sum',
        'applications': 'sum',
        'conversion_rate': 'mean'
    }).reset_index()

    return employee_summary

employee_performance = summarize_by_employee(processed_data)

# %%
employee_performance
# Out:
#          employee_name  lead_taken  tours_booked  applications  \
# 0                    0           0             0             0
# 1          Aaron Rahim           1             0             0
# 2          Abe Walkerr         272             5             3
# 3          Adrian Rafi         361            39             0
# 4           Aiden Moon         216            28             0
# 5        Albert Morgan           0             0             0
# 6            Ali Hamza          54             0             0
# 7         Alina Victor       13484           931           588
# 8          Areesa Gold         728            11             0
# 9          Ashir Ghori        3441           190           110
# 10         Camilla Ali       15337          1508           679
# 11       Damon Gilbert         215            17             6
# 12         Eva Pereira         159             0             0
# 13         Eva Yusyana        1854            51            27
# 14          Faye Ryann         299            24             3
# 15         Felix Emeka        9558           637           213
# 16          Frank Lois        1260             0             0
# 17        Frank Norris         999            13             0
# 18      Genevieve Gold        8270           475           654
# 19         Harry Quinn         367            11             5
# 20        Ivette Couto           0             0             0
# 21             Jim Lee         260            15             3
# 22         John Carlos         404            81            18
# 23    Justice Nwankere         122             0             0
# 24        Katie Tucker         607            36            36
# 25          Kevin Shaw         516            34            17
# 26          Kinza Gold        6598           215           107
# 27          Maaz Brown        2304           193            62
# 28         Mandy Quest         155             8             0
# 29        Maria Khalid        4833           175            35
# 30         Mary Farley           0             0             0
# 31       Mary Ogbewele        3475           289            90
# 32      Nabeeha Oliver        1043            62            27
# 33        Natalie Arif        3696           286           160
# 34        Noelle Imara           5             0             0
# 35         Pamela Ross       13957          1266           526
# 36     Patrick Ribeiro        5869             0             0
# 37        Rebecca Zara         743            57            19
# 38         Rehana Khan         195             0             0
# 39       Richard Crown        7525           609           177
# 40         Romeen Khan          71             0             0
# 41    Rooney Rodriguez        4989            68            30
# 42            Rose Sky           0             0             0
# 43        Salim Baloch        1293            25            26
# 44          Salma Arif         145             8             9
# 45           Sam Mubin        9168             7             6
# 46        Samuel Jones         271             9             0
# 47          Sana Lopez        8921           466           240
# 48        Sarah Kayani         795            19             0
# 49        Scott Abbott           7             0             0
# 50         Sean Garcia           0             0             0
# 51          Sid Andrew         433            36            14
# 52  Stephanie Chideluo         309            12             6
# 53   Sudhindra  Rao MS           0             0             0
# 54     Svetlana Soares        5849             0             0
# 55         Teresa Reid        1560           145            12
# 56             Tia Ali         397             0             0
# 57         Travis Reed          10             0             0
# 58       Umama Ishtiaq           0             0             0
#
#     conversion_rate
# 0          0.000000
# 1          0.000000
# 2          0.005268
# 3          0.000000
# 4          0.000000
# 5          0.000000
# 6          0.000000
# 7          0.066660
# 8          0.000000
# 9          0.037320
# 10         0.069197
# 11         0.028257
# 12         0.000000
# 13         0.010354
# 14         0.002771
# 15         0.024009
# 16         0.000000
# 17         0.000000
# 18         0.272013
# 19         0.004125
# 20         0.000000
# 21         0.011539
# 22         0.050327
# 23         0.000000
# 24         0.272985
# 25         0.044826
# 26         0.052239
# 27         0.025029
# 28         0.000000
# 29         0.010124
# 30         0.000000
# 31         0.027587
# 32         0.022456
# 33         0.190255
# 34         0.000000
# 35         0.115343
# 36         0.000000
# 37         0.059811
# 38         0.000000
# 39         0.054748
# 40         0.000000
# 41         0.012294
# 42         0.000000
# 43         0.061861
# 44         0.065642
# 45         0.013749
# 46         0.000000
# 47         0.088882
# 48         0.000000
# 49         0.000000
# 50         0.000000
# 51         0.008312
# 52         0.010634
# 53         0.000000
# 54         0.000000
# 55         0.004155
# 56         0.000000
# 57         0.000000
# 58         0.000000
